# %%
import glob

# %%
images = ["ch03_mseed_plot.png",
"obspy-trimmed-trace.png",
"obspy-structure.png",
"record-txt-file.png",
"ch03_mseed_plot_method.png",
"obspy-filter-mseed.png",

"softness.png",
"site-effect.png",
"basin.png",
"topography.png",
"bedrock-surface-outcrop-motion.png",
"raypaths_300.png",
"categorized_vacfs_mine.png",
"vacf_ssr_hvsr_ste.png",
"vacf_ssr_hvsr_stc.png",
"basin.png",
"nehpr_site_classification.png",

"matplotlib_empty_figure.png",
"matplotlib_figure_grid.png",
"matplotlib_figure_grid_tight_layout.png",
"pandas_fourier_dataframe.png",
"fourier_data_plot.png",
"fourier_data_plot_labels.png",
"fourier_data_plot_grid_ticks.png",
"fourier_data_plot_legend.png",
"matplotlib_mseed_plot.png",
"windows.png",
"arrivals.png",
"subplot_mosaic.png",

"tectonic-plates.png",
"fault-animation.gif",
"p-waves.gif",
"sh-waves.gif",
"sv-waves.gif",
"love-waves.gif",
"rayleigh-waves.gif",
"source-medium-station.png",
"seismic-phases.png",
"fault-type-general.png",
"fault-geometry.png",
"normal-slip-fault.gif",
"reverse-slip-fault.gif",
"strike-slip-fault.gif",

"file-structure.png",

"seismic-waveform.png",
"obspy-stream-filtered.png",
"arrivals.png",
"windows.png",
"trimmed.png",
"taper.png",
"fourier-plot.png"
]

# %%
import os, shutil
os.listdir("src/images")
# Out:
# ['arrivals.png',
#  'ascii-to-mseed-icon.png',
#  'basin.png',
#  'bedrock-surface-outcrop-motion.png',
#  'categorized_vacfs_mine.png',
#  'ch03_mseed_plot.png',
#  'ch03_mseed_plot_method.png',
#  'contact.png',
#  'cropped_seismogram.jpg',
#  'csv-icon.png',
#  'data-science.png',
#  'detrend-gif.gif',
#  'distance-between-points-icon.png',
#  'earthquakes_greece.png',
#  'edit-seismic-file-icon.png',
#  'empty-topic.png',
#  'emsc.jpg',
#  'excel-icon.png',
#  'faqs.png',
#  'fault-animation.gif',
#  'fault-geometry.png',
#  'fault-type-animation-start.jpg',
#  'fault-type-animation.gif',
#  'fault-type-general.png',
#  'fault-type-image-no-bg.png',
#  'fault-type-image.png',
#  'feedback.png',
#  'feedback.png.svg',
#  'file-manipulation-icon.png',
#  'file-structure.png',
#  'file-to-mseed-icon.png',
#  'fourier-gif.gif',
#  'fourier-graph-icon.png',
#  'fourier-icon.png',
#  'fourier-plot.png',
#  'fourier_data_plot.png',
#  'fourier_data_plot_grid_ticks.png',
# ...

# %%
import os
os.mkdir("nada")
for img in images:
    if img =="seismic-waveform.png":
        continue
    shutil.copy(f"src/images/{img}", "nada")
